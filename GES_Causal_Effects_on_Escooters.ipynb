# %%
# !pip install pgmpy

# %%
# !pip install dowhy

# %%
# !pip install causal-learn

# %%
import pandas as pd
import numpy as np
from pgmpy.estimators import PC
from sklearn.preprocessing import StandardScaler

from causallearn.search.ScoreBased.GES import ges


from causallearn.utils.GraphUtils import GraphUtils
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import io


from dowhy import CausalModel

# %%
data = pd.read_csv("output.csv")

# %%
threshold = len(data) * 0.5
data = data.dropna(thresh=threshold, axis=1)

# Dropping rows with any missing values
data = data.dropna()

# Encoding categorical variables (if any)
categorical_cols = data.select_dtypes(include=['object', 'category']).columns
data = pd.get_dummies(data, columns=categorical_cols, drop_first=True)

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
scaled_data = pd.DataFrame(scaled_data, columns=data.columns)

# %%
# default parameters
Record = ges(data)


# Visualization using pydot


pyd = GraphUtils.to_pydot(Record['G'],labels=list(data.columns))
tmp_png = pyd.create_png(f="png")
fp = io.BytesIO(tmp_png)
img = mpimg.imread(fp, format='png')
plt.axis('off')
plt.imshow(img)
plt.show()


# or save the graph
pyd.write_png('simple_test.png')

# %%
pyd

# %%
g=digraph{
    dpi=200;
    fontsize=18;
    GENDER [label=GENDER];
    AGE [label=AGE];
    EDUC [label=EDUC];
    EMP_STATUS_PRECOVID [label=EMP_STATUS_PRECOVID];
    EMP_STATUS_NOW [label=EMP_STATUS_NOW];
    STUDENT [label=STUDENT];
    INCOME_2019 [label=INCOME_2019];
    INCOME_CHANGED [label=INCOME_CHANGED];
    INCOME_2020 [label=INCOME_2020];
    HHSIZE [label=HHSIZE];
    N_VEHICLE [label=N_VEHICLE];
    N_HH_DLICENSE [label=N_HH_DLICENSE];
    DLICENSE [label=DLICENSE];
    MAIN_DRIVER [label=MAIN_DRIVER];
    DIVVY_BIKE [label=DIVVY_BIKE];
    REDUCEDFEE_TRANSIT [label=REDUCEDFEE_TRANSIT];
    DATAPLAN [label=DATAPLAN];
    EXERCISE [label=EXERCISE];
    DIS_CAT [label=DIS_CAT];
    RACE_CAT [label=RACE_CAT];
    ATTD_USAGE_FUTURE [label=ATTD_USAGE_FUTURE];

    GENDER -> AGE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> GENDER [arrowhead=normal, arrowtail=none, dir=both];
    GENDER -> DIVVY_BIKE [arrowhead=none, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> AGE [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> STUDENT [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> INCOME_2019 [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> AGE [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> DIS_CAT [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_NOW -> EMP_STATUS_PRECOVID [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> STUDENT [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> INCOME_2019 [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> HHSIZE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> DIVVY_BIKE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> REDUCEDFEE_TRANSIT [arrowhead=normal, arrowtail=none, dir=both];
    DATAPLAN -> EMP_STATUS_PRECOVID [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> EXERCISE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> RACE_CAT [arrowhead=normal, arrowtail=none, dir=both];
    STUDENT -> REDUCEDFEE_TRANSIT [arrowhead=normal, arrowtail=none, dir=both];
    INCOME_2019 -> INCOME_2020 [arrowhead=normal, arrowtail=none, dir=both];
    INCOME_CHANGED -> INCOME_2020 [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    REDUCEDFEE_TRANSIT -> HHSIZE [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> RACE_CAT [arrowhead=normal, arrowtail=none, dir=both];
    N_HH_DLICENSE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    N_HH_DLICENSE -> MAIN_DRIVER [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> MAIN_DRIVER [arrowhead=normal, arrowtail=none, dir=both];
    DATAPLAN -> DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
}
# Out:
#   File "<ipython-input-108-582b55673651>", line 2
#     dpi=200;
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
pyd.to_string()
# Out:
# 'digraph  {\ndpi=200;\nfontsize=18;\n0 [label=X1];\n0 [label=GENDER];\n1 [label=X2];\n1 [label=AGE];\n2 [label=X3];\n2 [label=EDUC];\n3 [label=X4];\n3 [label=EMP_STATUS_PRECOVID];\n4 [label=X5];\n4 [label=EMP_STATUS_NOW];\n5 [label=X6];\n5 [label=STUDENT];\n6 [label=X7];\n6 [label=INCOME_2019];\n7 [label=X8];\n7 [label=INCOME_CHANGED];\n8 [label=X9];\n8 [label=INCOME_2020];\n9 [label=X10];\n9 [label=HHSIZE];\n10 [label=X11];\n10 [label=N_VEHICLE];\n11 [label=X12];\n11 [label=N_HH_DLICENSE];\n12 [label=X13];\n12 [label=DLICENSE];\n13 [label=X14];\n13 [label=MAIN_DRIVER];\n14 [label=X15];\n14 [label=DIVVY_BIKE];\n15 [label=X16];\n15 [label=REDUCEDFEE_TRANSIT];\n16 [label=X17];\n16 [label=DATAPLAN];\n17 [label=X18];\n17 [label=EXERCISE];\n18 [label=X19];\n18 [label=DIS_CAT];\n19 [label=X20];\n19 [label=RACE_CAT];\n20 [label=X21];\n20 [label=ATTD_USAGE_FUTURE];\n0 -> 1  [arrowhead=normal, arrowtail=none, dir=both];\n3 -> 0  [arrowhead=normal, arrowtail=none, dir=both];\n0 -> 14  [arrowhe
# ...

# %%
model=CausalModel(
        data = data,
        treatment=["RACE_CAT"],
        outcome=["ATTD_USAGE_FUTURE"],
        graph="""digraph{
    dpi=200;
    fontsize=18;
    GENDER [label=GENDER];
    AGE [label=AGE];
    EDUC [label=EDUC];
    EMP_STATUS_PRECOVID [label=EMP_STATUS_PRECOVID];
    EMP_STATUS_NOW [label=EMP_STATUS_NOW];
    STUDENT [label=STUDENT];
    INCOME_2019 [label=INCOME_2019];
    INCOME_CHANGED [label=INCOME_CHANGED];
    INCOME_2020 [label=INCOME_2020];
    HHSIZE [label=HHSIZE];
    N_VEHICLE [label=N_VEHICLE];
    N_HH_DLICENSE [label=N_HH_DLICENSE];
    DLICENSE [label=DLICENSE];
    MAIN_DRIVER [label=MAIN_DRIVER];
    DIVVY_BIKE [label=DIVVY_BIKE];
    REDUCEDFEE_TRANSIT [label=REDUCEDFEE_TRANSIT];
    DATAPLAN [label=DATAPLAN];
    EXERCISE [label=EXERCISE];
    DIS_CAT [label=DIS_CAT];
    RACE_CAT [label=RACE_CAT];
    ATTD_USAGE_FUTURE [label=Intention to use];

    GENDER -> DIVVY_BIKE [arrowhead=none, arrowtail=none, dir=both];
    AGE -> STUDENT [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> INCOME_2019 [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    AGE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> EDUC [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_NOW -> EMP_STATUS_PRECOVID [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> STUDENT [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> INCOME_2019 [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> HHSIZE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> DIVVY_BIKE [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> REDUCEDFEE_TRANSIT [arrowhead=normal, arrowtail=none, dir=both];
    DATAPLAN -> EMP_STATUS_PRECOVID [arrowhead=normal, arrowtail=none, dir=both];
    EMP_STATUS_PRECOVID -> EXERCISE [arrowhead=normal, arrowtail=none, dir=both];
    STUDENT -> REDUCEDFEE_TRANSIT [arrowhead=normal, arrowtail=none, dir=both];
    INCOME_2019 -> INCOME_2020 [arrowhead=normal, arrowtail=none, dir=both];
    INCOME_CHANGED -> INCOME_2020 [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    HHSIZE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    REDUCEDFEE_TRANSIT -> HHSIZE [arrowhead=normal, arrowtail=none, dir=both];
    N_HH_DLICENSE -> N_VEHICLE [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> N_HH_DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    N_HH_DLICENSE -> MAIN_DRIVER [arrowhead=normal, arrowtail=none, dir=both];
    DLICENSE -> MAIN_DRIVER [arrowhead=normal, arrowtail=none, dir=both];
    DATAPLAN -> DLICENSE [arrowhead=normal, arrowtail=none, dir=both];
    N_VEHICLE -> ATTD_USAGE_FUTURE [arrowhead=normal, arrowtail=none, dir=both];
    RACE_CAT -> ATTD_USAGE_FUTURE [arrowhead=normal, arrowtail=none, dir=both];
    EXERCISE -> DIVVY_BIKE [arrowhead=normal, arrowtail=none, dir=both];
    DIVVY_BIKE -> ATTD_USAGE_FUTURE [arrowhead=normal, arrowtail=none, dir=both];
      }"""
        )
# Out:
# ERROR:dowhy.causal_graph:Error: Pygraphviz cannot be loaded. No module named 'pygraphviz'
# Trying pydot ...

# %%
model.view_model()

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print(identified_estimand)
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ───────────(E[ATTD_USAGE_FUTURE])
# d[RACE_CAT]
# Estimand assumption 1, Unconfoundedness: If U→{RACE_CAT} and U→ATTD_USAGE_FUTURE then P(ATTD_USAGE_FUTURE|RACE_CAT,,U) = P(ATTD_USAGE_FUTURE|RACE_CAT,)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!

# %%
causal_estimate = model.estimate_effect(identified_estimand,
        method_name="backdoor.linear_regression")

# %%
print(causal_estimate)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#      d
# ───────────(E[ATTD_USAGE_FUTURE])
# d[RACE_CAT]
# Estimand assumption 1, Unconfoundedness: If U→{RACE_CAT} and U→ATTD_USAGE_FUTURE then P(ATTD_USAGE_FUTURE|RACE_CAT,,U) = P(ATTD_USAGE_FUTURE|RACE_CAT,)
#
# ## Realized estimand
# b: ATTD_USAGE_FUTURE~RACE_CAT+RACE_CAT*STUDENT+RACE_CAT*EMP_STATUS_PRECOVID+RACE_CAT*EMP_STATUS_NOW+RACE_CAT*DATAPLAN+RACE_CAT*N_HH_DLICENSE+RACE_CAT*AGE+RACE_CAT*GENDER+RACE_CAT*HHSIZE+RACE_CAT*EXERCISE+RACE_CAT*N_VEHICLE+RACE_CAT*DIVVY_BIKE+RACE_CAT*REDUCEDFEE_TRANSIT+RACE_CAT*DLICENSE
# Target units: ate
#
# ## Estimate
# Mean value: 0.023423681581763223
